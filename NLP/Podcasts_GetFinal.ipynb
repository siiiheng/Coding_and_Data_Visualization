# %%
import sqlite3
import numpy as np
import pandas as pd
import tensorflow as tf
import re

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("database.sqlite")
reviews = pd.read_sql_query("SELECT * from reviews", con)

# Verify that result of SQL query is stored in the dataframe
reviews.head()
# Out:
#                          podcast_id  \
# 0  c61aa81c9b929a66f0c1db6cbe5d8548
# 1  c61aa81c9b929a66f0c1db6cbe5d8548
# 2  ad4f2bf69c72b8db75978423c25f379e
# 3  ad4f2bf69c72b8db75978423c25f379e
# 4  ad4f2bf69c72b8db75978423c25f379e
#
#                                               title  \
# 0                               really interesting!
# 1  Must listen for anyone interested in the arts!!!
# 2                                 nauseatingly left
# 3                                   Diverse stories
# 4                                              👍👍👍👍
#
#                                              content  rating        author_id  \
# 0  Thanks for providing these insights.  Really e...       5  F7E5A318989779D
# 1  Super excited to see this podcast grow. So man...       5  F6BF5472689BD12
# 2  I'm a liberal myself, but its pretty obvious a...       1  1AB95B8E6E1309E
# 3  I find Tedx talks very inspirational but I oft...       5  11BB760AA5DEBD1
# 4                I love this podcast, it is so good.       5  D86032C8E57D15A
#
#                   created_at
# 0  2018-04-24T12:05:16-07:00
# 1  2018-05-09T18:14:32-07:00
# 2  2019-06-11T14:53:39-07:00
# 3  2018-05-31T13:08:09-07:00
# 4  2019-06-19T13:56:05-07:00

# %%
reviews.shape
# Out:
# (2004000, 6)

# %%
podcasts = pd.read_sql_query("SELECT * from podcasts", con)

# Verify that result of SQL query is stored in the dataframe
podcasts.rename(columns={'title': 'podcast_title'}, inplace = True)
podcasts.head()
# Out:
#                          podcast_id   itunes_id  \
# 0  a00018b54eb342567c94dacfb2a3e504  1313466221
# 1  a00043d34e734b09246d17dc5d56f63c   158973461
# 2  a0004b1ef445af9dc84dad1e7821b1e3   139076942
# 3  a00071f9aaae9ac725c3a586701abf4d  1332508972
# 4  a000aa69852b276565c4f5eb9cdd999b  1342447811
#
#                                     slug  \
# 0                         scaling-global
# 1  cornerstone-baptist-church-of-orlando
# 2            mystery-dancing-in-the-dark
# 3                      kts-money-matters
# 4                        speedway-soccer
#
#                                           itunes_url  \
# 0  https://podcasts.apple.com/us/podcast/scaling-...
# 1  https://podcasts.apple.com/us/podcast/cornerst...
# 2  https://podcasts.apple.com/us/podcast/mystery-...
# 3  https://podcasts.apple.com/us/podcast/kts-mone...
# 4  https://podcasts.apple.com/us/podcast/speedway...
#
#                            podcast_title
# 0                         Scaling Global
# 1  Cornerstone Baptist Church of Orlando
# 2           Mystery: Dancing in the Dark
# 3                      KTs Money Matters
# 4                        Speedway Soccer

# %%
podcasts.shape
# Out:
# (109216, 5)

# %%
categories = pd.read_sql_query("SELECT * from categories", con)

# Verify that result of SQL query is stored in the dataframe
categories.head()
# Out:
#                          podcast_id              category
# 0  c61aa81c9b929a66f0c1db6cbe5d8548                  arts
# 1  c61aa81c9b929a66f0c1db6cbe5d8548  arts-performing-arts
# 2  c61aa81c9b929a66f0c1db6cbe5d8548                 music
# 3  ad4f2bf69c72b8db75978423c25f379e                  arts
# 4  ad4f2bf69c72b8db75978423c25f379e           arts-design

# %%
categories.shape
# Out:
# (211243, 2)

# %%
def get_main_cat(line):
    line = line.replace(line, re.findall(r'\b([a-zA-Z]+)\b', line)[0])
    
    return line

# %%
categories['category'] = categories['category'].apply(lambda x: get_main_cat(x))
categories.head()
# Out:
#                          podcast_id category
# 0  c61aa81c9b929a66f0c1db6cbe5d8548     arts
# 1  c61aa81c9b929a66f0c1db6cbe5d8548     arts
# 2  c61aa81c9b929a66f0c1db6cbe5d8548    music
# 3  ad4f2bf69c72b8db75978423c25f379e     arts
# 4  ad4f2bf69c72b8db75978423c25f379e     arts

# %%
categories['category'].unique()
# Out:
# array(['arts', 'music', 'education', 'society', 'leisure', 'technology',
#        'fiction', 'true', 'health', 'history', 'comedy', 'tv', 'kids',
#        'religion', 'business', 'news', 'spirituality', 'science',
#        'christianity', 'government', 'sports', 'hinduism', 'judaism',
#        'islam', 'buddhism'], dtype=object)

# %%
def replace_cat(line):
    line = re.sub(r'\b(true)\b', 'crime', line)
    line = re.sub(r'\b(christianity|hinduism|judaism|islam|buddhism|spirituality)\b', 'religion', line)
    return line

# %%
categories['category'] = categories['category'].apply(lambda x: replace_cat(x))
categories.head()
# Out:
#                          podcast_id category
# 0  c61aa81c9b929a66f0c1db6cbe5d8548     arts
# 1  c61aa81c9b929a66f0c1db6cbe5d8548     arts
# 2  c61aa81c9b929a66f0c1db6cbe5d8548    music
# 3  ad4f2bf69c72b8db75978423c25f379e     arts
# 4  ad4f2bf69c72b8db75978423c25f379e     arts

# %%
categories.drop_duplicates(subset='podcast_id', keep="first", inplace = True)
categories.shape
# Out:
# (109216, 2)

# %%
df = pd.merge(reviews, podcasts, on=['podcast_id'], how = 'inner')
df = pd.merge(df, categories, on=['podcast_id'], how = 'inner')
df.shape
# Out:
# (1979519, 11)

# %%
df
# Out:
#                                podcast_id  \
# 0        c61aa81c9b929a66f0c1db6cbe5d8548
# 1        c61aa81c9b929a66f0c1db6cbe5d8548
# 2        ad4f2bf69c72b8db75978423c25f379e
# 3        ad4f2bf69c72b8db75978423c25f379e
# 4        ad4f2bf69c72b8db75978423c25f379e
# ...                                   ...
# 1979514  deeee82605b10fd53225121291fb533a
# 1979515  deeee82605b10fd53225121291fb533a
# 1979516  ee05f560fe1defe37b673f67c020b1bb
# 1979517  fb98841a677ab948b1bc90900ba8d0d8
# 1979518  fb98841a677ab948b1bc90900ba8d0d8
#
#                                                     title  \
# 0                                     really interesting!
# 1        Must listen for anyone interested in the arts!!!
# 2                                       nauseatingly left
# 3                                         Diverse stories
# 4                                                    👍👍👍👍
# ...                                                   ...
# 1979514                 Great Coffee, People, and Podcast
# 1979515                                 The first of many
# 1979516                                  love the podcast
# 1979517                                       Just Great!
# 1979518                          Can’t wait for Wednesday
#
#                                                    content  rating  \
# 0        Thanks for providing these insights.  Really e...       5
# 1        Super excited to see this podcast grow. So man...       5
# 2        I'm a liberal myself, but its pretty obvious a...       1
# 3        I find Tedx talks very inspirational but I oft...       5
# 4                      I love this podcast, it is so good.       5
# ...                                                    ...     ...
# 1979514  On top of incredible coffee, these guys are pu...       5
# 1979515        Great job guys! Hope you see great success.       5
# 1979516  just wish it was a little longer like 60 mins ...       5
# 1979517  This is probably a weekly highlight for me! Lo...       5
# 1979518  Just cancelled my SiriusXM subscription. Who n...       5
#
#                author_id                 created_at   itunes_id  \
# 0        F7E5A318989779D  2018-04-24T12:05:16-07:00  1373261997
# 1        F6BF5472689BD12  2018-05-09T18:14:32-07:00  1373261997
# 2        1AB95B8E6E1309E  2019-06-11T14:53:39-07:00   160904630
# 3        11BB760AA5DEBD1  2018-05-31T13:08:09-07:00   160904630
# 4        D86032C8E57D15A  2019-06-19T13:56:05-07:00   160904630
# ...                  ...                        ...         ...
# 1979514  6068D1F74D4CC1F  2021-09-02T14:13:40-07:00  1572279346
# 1979515  0179E9398E85CA1  2021-06-15T20:30:23-07:00  1572279346
# 1979516  8585EA0C5A446EC  2021-01-13T21:25:21-07:00  1477693877
# 1979517  CF99C44A93FC389  2020-09-24T07:15:57-07:00  1529801099
# 1979518  90A3771A6082847  2020-10-24T07:18:22-07:00  1529801099
#
#                                 slug  \
# 0         backstage-at-tilles-center
# 1         backstage-at-tilles-center
# 2                    ted-talks-daily
# 3                    ted-talks-daily
# 4                    ted-talks-daily
# ...                              ...
# 1979514  the-backwoods-grind-podcast
# 1979515  the-backwoods-grind-podcast
# 1979516         the-curbside-podcast
# 1979517               tlg-roundtable
# 1979518               tlg-roundtable
#
#                                                 itunes_url  \
# 0        https://podcasts.apple.com/us/podcast/backstag...
# 1        https://podcasts.apple.com/us/podcast/backstag...
# 2        https://podcasts.apple.com/us/podcast/ted-talk...
# 3        https://podcasts.apple.com/us/podcast/ted-talk...
# 4        https://podcasts.apple.com/us/podcast/ted-talk...
# ...                                                    ...
# 1979514  https://podcasts.apple.com/us/podcast/the-back...
# 1979515  https://podcasts.apple.com/us/podcast/the-back...
# 1979516  https://podcasts.apple.com/us/podcast/the-curb...
# 1979517  https://podcasts.apple.com/us/podcast/tlg-roun...
# 1979518  https://podcasts.apple.com/us/podcast/tlg-roun...
#
#                        podcast_title category
# 0         Backstage at Tilles Center     arts
# 1         Backstage at Tilles Center     arts
# 2                    TED Talks Daily     arts
# 3                    TED Talks Daily     arts
# 4                    TED Talks Daily     arts
# ...                              ...      ...
# 1979514  The Backwoods Grind Podcast   sports
# 1979515  The Backwoods Grind Podcast   sports
# 1979516         The Curbside Podcast  leisure
# 1979517               TLG Roundtable   sports
# 1979518               TLG Roundtable   sports
#
# [1979519 rows x 11 columns]

# %%
df['category'].unique()
# Out:
# array(['arts', 'society', 'fiction', 'history', 'comedy', 'music',
#        'leisure', 'education', 'kids', 'religion', 'business', 'news',
#        'tv', 'health', 'sports', 'science', 'technology', 'government',
#        'crime'], dtype=object)

# %%
df.to_csv('podcast_final.csv')

# %%
df_sample = df.sample(200000).reset_index(drop = True)

# %%
df_sample
# Out:
#                               podcast_id                            title  \
# 0       eb8be8dd261e2c7ad359fc1100e00d36                              Wow
# 1       ff4c45ee931ee137e635bf25cf812603                     Erin A Titus
# 2       e87cebeb33762a0fd09345bf468f6494         5 stars not for youtubes
# 3       e0b112db2630c309e68c76259d6f3dd8               Wonderfully funny!
# 4       ac6835b75edb8475163934ae40ea9f50              Holy F***ing S*** !
# ...                                  ...                              ...
# 199995  e7be0b6e726ac3f4cb1545bdf48830e8             Create your own luck
# 199996  e18101f446800acac315bc8c9cc088fd  Like hanging out with a friend!
# 199997  eff0d55df3b0d1ec61b6fb87faac2398                Keep them coming!
# 199998  d283aab5fd78b2608a87094381eb7b40                     Erwin little
# 199999  f4b308e75ed429602e806eb76b5a5546     Get some! ... PERSPECTIVE!!!
#
#                                                   content  rating  \
# 0       I’m just speechless...Listing to this podcast ...       5
# 1                Total Irish American from my da. Love it       5
# 2       5 stARS FOR my Boi EaThilaN kLienybOI\nRead yo...       5
# 3                Definitely a great podcast to listen to!       5
# 4       This podcast is funny. I like listening to it ...       5
# ...                                                   ...     ...
# 199995  The interview is excellent and really helps yo...       5
# 199996  Listening to this podcast is like catching up ...       5
# 199997  They do their research and keep listeners enga...       5
# 199998  Great interview. Down to earth conversation. N...       5
# 199999  These ladies are having the tough conversation...       5
#
#               author_id                 created_at   itunes_id  \
# 0       354021BBAD70826  2021-05-26T08:36:35-07:00  1492139540
# 1       EEBAB0E98722505  2022-05-01T19:30:27-07:00   363368392
# 2       2EC77A5CC218BC8  2019-07-31T13:17:16-07:00  1186098620
# 3       B871176FE7993B1  2020-08-05T18:45:46-07:00  1522764294
# 4       C9A897B4EDAA221  2020-10-28T14:20:20-07:00  1504297576
# ...                 ...                        ...         ...
# 199995  328368602D3E5A4  2019-12-17T18:24:48-07:00  1487739752
# 199996  C622C2BB8366912  2022-06-22T09:51:25-07:00  1586672755
# 199997  92890FC763BB734  2019-02-21T07:25:15-07:00  1451109634
# 199998  7F421CDDAFDA7D9  2019-04-29T17:16:10-07:00  1460623879
# 199999  6EC6646995E78D2  2019-01-03T11:50:39-07:00   885960517
#
#                          slug  \
# 0        effective-compassion
# 1       irish-history-podcast
# 2                  h3-podcast
# 3                   disc-only
# 4       up-close-and-personal
# ...                       ...
# 199995          she-finds-joy
# 199996          beck-and-call
# 199997            throughline
# 199998        tmi-with-teresa
# 199999            guys-we-f-d
#
#                                                itunes_url  \
# 0       https://podcasts.apple.com/us/podcast/effectiv...
# 1       https://podcasts.apple.com/us/podcast/irish-hi...
# 2       https://podcasts.apple.com/us/podcast/h3-podca...
# 3       https://podcasts.apple.com/us/podcast/disc-onl...
# 4       https://podcasts.apple.com/us/podcast/up-close...
# ...                                                   ...
# 199995  https://podcasts.apple.com/us/podcast/she-find...
# 199996  https://podcasts.apple.com/us/podcast/beck-and...
# 199997  https://podcasts.apple.com/us/podcast/throughl...
# 199998  https://podcasts.apple.com/us/podcast/tmi-with...
# 199999  https://podcasts.apple.com/us/podcast/guys-we-...
#
#                 podcast_title  category
# 0        Effective Compassion      news
# 1       Irish History Podcast   history
# 2                  H3 Podcast    comedy
# 3                   Disc Only    comedy
# 4       Up Close and Personal    comedy
# ...                       ...       ...
# 199995          She Finds Joy  business
# 199996          Beck and Call   society
# 199997            Throughline   history
# 199998        TMI with Teresa   society
# 199999         Guys We F****d    comedy
#
# [200000 rows x 11 columns]

# %%
df_sample.to_csv('podcast_sample.csv')
